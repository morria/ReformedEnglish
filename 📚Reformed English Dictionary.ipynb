# %% [markdown]
# # Reformed English Dictionary
#
# This document explores what it might look like to map english words to phonetic spellings. The phonetic dictionary is from [CMU Sphinx](https://github.com/cmusphinx/cmudict).

# %%
import re
from random import shuffle
import textwrap

# %%
# Read the phonetic alphabet
phonetic_alphabet = {}
with open("cmudict/cmudict.phones") as file:
    for line in file:
       (phoneme, type) = line.split()
       phonetic_alphabet[str(phoneme)] = type
print(phonetic_alphabet)
# Out:
# {'AA': 'vowel', 'AE': 'vowel', 'AH': 'vowel', 'AO': 'vowel', 'AW': 'vowel', 'AY': 'vowel', 'B': 'stop', 'CH': 'affricate', 'D': 'stop', 'DH': 'fricative', 'EH': 'vowel', 'ER': 'vowel', 'EY': 'vowel', 'F': 'fricative', 'G': 'stop', 'HH': 'aspirate', 'IH': 'vowel', 'IY': 'vowel', 'JH': 'affricate', 'K': 'stop', 'L': 'liquid', 'M': 'nasal', 'N': 'nasal', 'NG': 'nasal', 'OW': 'vowel', 'OY': 'vowel', 'P': 'stop', 'R': 'liquid', 'S': 'fricative', 'SH': 'fricative', 'T': 'stop', 'TH': 'fricative', 'UH': 'vowel', 'UW': 'vowel', 'V': 'fricative', 'W': 'semivowel', 'Y': 'semivowel', 'Z': 'fricative', 'ZH': 'fricative'}

# %%
# Read the dictionary
dictionary = {}
with open("cmudict/cmudict.dict") as file:
    for line in file:
       list = line.split('#')[0].split()
       dictionary[str(list[0])] = list[1::]

# %%
# Make a map from phoneme to how frequently it appears
phoneme_frequency = {}
for word in dictionary.keys():
    for phoneme in dictionary[word]:
        if phoneme not in phoneme_frequency:
            phoneme_frequency[phoneme] = 0
        phoneme_frequency[phoneme] += 1
sorted(phoneme_frequency.items())
# Out:
# [('AA0', 4966),
#  ('AA1', 16960),
#  ('AA2', 3368),
#  ('AE0', 1730),
#  ('AE1', 16910),
#  ('AE2', 3404),
#  ('AH0', 63133),
#  ('AH1', 6873),
#  ('AH2', 1143),
#  ('AO0', 1505),
#  ('AO1', 8176),
#  ('AO2', 1886),
#  ('AW0', 377),
#  ('AW1', 2346),
#  ('AW2', 652),
#  ('AY0', 1201),
#  ('AY1', 6930),
#  ('AY2', 3393),
#  ('B', 21432),
#  ('CH', 4954),
#  ('D', 32558),
#  ('DH', 587),
#  ('EH0', 2928),
#  ('EH1', 20837),
#  ('EH2', 3932),
#  ('ER0', 23954),
#  ('ER1', 4581),
#  ('ER2', 612),
#  ('EY0', 965),
#  ('EY1', 9358),
#  ('EY2', 3416),
#  ('F', 13961),
#  ('G', 13689),
#  ('HH', 9376),
#  ('IH0', 30198),
#  ('IH1', 15769),
#  ('IH2', 4462),
#  ('IY0', 22141),
#  ('IY1', 10321),
#  ('IY2', 2640),
#  ('JH', 6394),
#  ('K', 43077),
#  ('L', 49963),
#  ('M', 29741),
#  ('N', 61234),
#  ('NG', 9989),
#  ('OW0', 8212),
#  ('OW1', 8667),
#  ('OW2', 2458),
#  ('OY0', 124),
#  ('OY1', 957),
#  ('OY2', 207),
#  ('P', 19988),
#  ('R', 46468),
#  ('S', 50432),
#  ('SH', 8812),
#  ('T', 49074),
#  ('TH', 2943),
#  ('UH0', 255),
#  ('UH1', 1601),
#  ('UH2', 478),
#  ('UW0', 2060),
#  ('UW1', 6712),
#  ('UW2', 1195),
#  ('V', 10810),
#  ('W', 8977),
#  ('Y', 5263),
#  ('Z', 28217),
#  ('ZH', 574)]

# %%
# Read the top 1,000 most frequently used English words
popular_words = []
with open("popular_words") as file:
    for line in file:
        popular_words.append(line.strip().lower())

# Get a phonetic spelling of each popular word
popular_dictionary = {}
for word in popular_words:
    if word in dictionary:
        popular_dictionary[word] = dictionary[word]
        
examples = {}
for phoneme in phoneme_frequency:
    s = [x for x in popular_dictionary if phoneme in popular_dictionary[x]]
    shuffle(s)
    examples[phoneme] = s[:5]

print("example_words = {")
for k, v in sorted(examples.items()):
    print("    '{}': {},".format(k, v))
print("}")
# Out:
# example_words = {
#     'AA0': ['participant'],
#     'AA1': ['policy', 'far', 'watch', 'project', 'party'],
#     'AA2': ['responsibility', 'somebody', 'population', 'operation', 'particularly'],
#     'AE0': ['activity', 'campaign', 'accept', 'administration'],
#     'AE1': ['glass', 'plant', 'challenge', 'chance', 'tax'],
#     'AE2': ['program', 'democrat'],
#     'AH0': ['social', 'provide', 'position', 'interest', 'record'],
#     'AH1': ['public', 'husband', 'once', 'must', 'love'],
#     'AH2': ['everyone', 'understand', 'whatever', 'anyone', 'someone'],
#     'AO0': ['already', 'resource'],
#     'AO1': ['draw', 'short', 'performance', 'your', 'wall'],
#     'AO2': ['organization', 'although'],
#     'AW0': [],
#     'AW1': ['out', 'account', 'throughout', 'sound', 'without'],
#     'AW2': ['however'],
#     'AY0': ['identify', 'idea'],
#     'AY1': ['describe', 'site', 'entire', 'try', 'violence'],
#     'AY2': ['myself', 'recognize', 'environmental', 'realize', 'identify'],
#     'B': ['member', 'maybe', 'body', 'both', 'better'],
#     'CH': ['question', 'chair', 'check', 'watch', 'charge'],
#     'D': ['tend', 'under', 'send', 'second', 'hard'],
#     'DH': ['them', 'mother', 'that', 'those', 'others'],
#     'EH0': ['technology', 'employee', 'decade', 'themselves', 'project'],
#     'EH1': ['prevent', 'western', 'general', 'expert', 'seven'],
#     'EH2': ['education', 'represent', 'generation', 'economic', 'democratic'],
#     'ER0': ['discover', 'after', 'natural', 'forget', 'cultural'],
#     'ER1': ['research', 'current', 'determine', 'personal', 'person'],
#     'ER2': ['network'],
#     'EY0': ['candidate', 'maintain'],
#     'EY1': ['stay', 'patient', 'page', 'same', 'play'],
#     'EY2': ['always', 'newspaper', 'indicate'],
#     'F': ['beautiful', 'field', 'perform', 'forward', 'laugh'],
#     'G': ['goal', 'exactly', 'finger', 'example', 'begin'],
#     'HH': ['high', 'ahead', 'head', 'how', 'home'],
#     'IH0': ['something', 'discussion', 'personal', 'environment', 'beyond'],
#     'IH1': ['building', 'minute', 'spring', 'wish', 'military'],
#     'IH2': ['politics', 'situation', 'inside', 'information', 'impact'],
#     'IY0': ['property', 'body', 'especially', 'family', 'already'],
#     'IY1': ['each', 'seat', 'tree', 'heat', 'senior'],
#     'IY2': ['reality', 'require', 'ability', 'magazine', 'probably'],
#     'JH': ['challenge', 'huge', 'manager', 'join', 'general'],
#     'K': ['experience', 'bank', 'indicate', 'public', 'economic'],
#     'L': ['usually', 'girl', 'fill', 'particularly', 'lie'],
#     'M': ['game', 'crime', 'middle', 'month', 'mr'],
#     'N': ['center', 'human', 'billion', 'investment', 'own'],
#     'NG': ['painting', 'congress', 'bring', 'spring', 'everything'],
#     'OW0': ['also', 'follow', 'window', 'hotel'],
#     'OW1': ['vote', 'program', 'road', 'show', 'growth'],
#     'OW2': ['almost', 'radio'],
#     'OY0': [],
#     'OY1': ['boy', 'point', 'voice', 'employee', 'oil'],
#     'OY2': [],
#     'P': ['responsibility', 'represent', 'explain', 'pain', 'simply'],
#     'R': ['problem', 'degree', 'president', 'grow', 'support'],
#     'S': ['some', 'stage', 'study', 'course', 'perhaps'],
#     'SH': ['nation', 'machine', 'station', 'sexual', 'mission'],
#     'T': ['trade', 'reflect', 'must', 'article', 'still'],
#     'TH': ['mouth', 'method', 'thank', 'health', 'south'],
#     'UH0': [],
#     'UH1': ['woman', 'good', 'book', 'put', 'security'],
#     'UH2': [],
#     'UW0': ['into', 'throughout', 'continue', 'issue', 'value'],
#     'UW1': ['to', 'you', 'include', 'produce', 'including'],
#     'UW2': ['interview', 'actually'],
#     'V': ['behavior', 'evening', 'government', 'private', 'visit'],
#     'W': ['whether', 'quite', 'everyone', 'way', 'one'],
#     'Y': ['figure', 'few', 'particular', 'you', 'yard'],
#     'Z': ['present', 'husband', 'season', 'music', 'example'],
#     'ZH': ['measure', 'decision', 'television', 'usually'],
# }

# %%
# Map phonemes to strings that may represent them.
phonemes_to_letters = {
    'AA': 'a',
    'AA1': 'o',
    'AE': 'a',
    'AH': 'a',
    'AH0': 'ah',
    'AH1': 'u',
    'AO': 'o',
    'A01': 'o',
    'AW': 'aw',
    'AW1': 'aw',
    'AY': 'i',
    'AY1': 'ii',
    'B': 'b',
    'CH': 'ch',
    'D': 'd',
    'DH': 'th',
    'EH': 'e',
    'EH1': 'eh',
    'ER': 'er',
    'ER0': 'er',
    'EY': 'ey',
    'F': 'f',
    'G': 'g',
    'HH': 'h',
    'IH': 'i',
    'IY': 'iy',
    'IY1': 'ee',
    'JH': 'j',
    'K': 'k',
    'L': 'l',
    'M': 'm',
    'N': 'n',
    'NG': 'ng',
    'OW': 'ow',
    'OY': 'oy',
    'P': 'p',
    'R': 'r',
    'S': 's',
    'SH': 'sh',
    'T': 't',
    'TH': 'th',
    'UH': 'u',
    'UW': 'uw',
    'V': 'v',
    'W': 'w',
    'Y': 'y',
    'Z': 'z',
    'ZH': 'z'
}

# %%
# Map a phoneme to a string representing it under the new dictionary
def mapPhoneme(phoneme):
    if phoneme in phonemes_to_letters:
        return phonemes_to_letters[phoneme]
    return phonemes_to_letters[re.split("[0-9]", phoneme)[0]]

# Map a word to a new spelling for that word
def mapWord(word):
    return ''.join(mapPhoneme(phoneme) for phoneme in dictionary[word.lower()])

def mapSloppyWord(sloppyWord):
    terms = re.split('[^a-z]$', sloppyWord.lower())
    for term in terms:
        if term in dictionary:
            sloppyWord = sloppyWord.lower().replace(term, mapWord(term))
    return sloppyWord

# Map a paragraph to a paragraph under the new dictionary
def mapParagraph(paragraph):
    return ' '.join(map(mapSloppyWord, paragraph.split()))

# %%
# Look at some example words under the new spelling
for word in popular_words:
    print("{} → {}".format(word, mapWord(word)))
# Out:
# a → ah
# ability → ahbilahtiy
# able → eybahl
# about → ahbawt
# above → ahbuv
# accept → aksehpt
# according → ahkording
# account → ahkawnt
# across → ahkros
# act → akt
# action → akshahn
# activity → aktivahtiy
# actually → akchuwahliy
# add → ad
# address → adres
# administration → administreyshahn
# admit → ahdmit
# adult → ahdult
# affect → ahfehkt
# after → after
# again → ahgehn
# against → ahgehnst
# age → eyj
# agency → eyjahnsiy
# agent → eyjahnt
# ago → ahgow
# agree → ahgree
# agreement → ahgreemahnt
# ahead → ahhehd
# air → ehr
# all → ol
# allow → ahlaw
# almost → olmowst
# alone → ahlown
# along → ahlong
# already → olrehdiy
# also → olsow
# although → olthow
# always → olweyz
# american → ahmehrahkahn
# among → ahmung
# amount → ahmawnt
# analysis → ahnalahsahs
# and → ahnd
# animal → anahmahl
# another → ahnuther
# answer → anser
# any → ehniy
# anyone → ehniywan
# anything → ehniything
# appear → ahpir
# apply → ahplii
# approach → ahprowch
# area → ehriyah
# argue → orgyuw
# arm → orm
# around → erawnd
# arrive → eriiv
# art → ort
# article → ortahkahl
# artist → ortahst
# as → az
# ask → ask
# assume → ahsuwm
# at → at
# attack → ahtak
# attention → ahtehnshahn
# attorney → ahterniy
# audience → odiyahns
# author → other
# authority → ahthorahtiy
# available → ahveylahbahl
# avoid → ahvoyd
# away → ahwey
# baby → beybiy
# back → bak
# bad → bad
# bag → bag
# ball → bol
# bank → bangk
# bar → bor
# base → beys
# be → bee
# beat → beet
# beautiful → byuwtahfahl
# because → bikoz
# become → bikum
# bed → behd
# before → bifor
# begin → bigin
# behavior → biheyvyer
# behind → bihiind
# believe → bileev
# benefit → behnahfit
# best → behst
# better → behter
# between → bitween
# beyond → biond
# big → big
# bill → bil
# billion → bilyahn
# bit → bit
# black → blak
# blood → blud
# blue → bluw
# board → bord
# body → bodiy
# book → buk
# born → born
# both → bowth
# box → boks
# boy → boy
# break → breyk
# bring → bring
# brother → bruther
# budget → bujit
# build → bild
# building → bilding
# business → biznahs
# but → but
# buy → bii
# by → bii
# call → kol
# camera → kamerah
# campaign → kampeyn
# can → kan
# cancer → kanser
# candidate → kandahdeyt
# capital → kapahtahl
# car → kor
# card → kord
# care → kehr
# career → kerir
# carry → kariy
# case → keys
# catch → kach
# cause → koz
# cell → sehl
# center → sehnter
# central → sehntrahl
# century → sehncheriy
# certain → sertahn
# certainly → sertahnliy
# chair → chehr
# challenge → chalahnj
# chance → chans
# change → cheynj
# character → kehrikter
# charge → chorj
# check → chehk
# child → chiild
# choice → choys
# choose → chuwz
# church → cherch
# citizen → sitahzahn
# city → sitiy
# civil → sivahl
# claim → kleym
# class → klas
# clear → klir
# clearly → klirliy
# close → klows
# coach → kowch
# cold → kowld
# collection → kahlehkshahn
# college → kolij
# color → kuler
# come → kum
# commercial → kahmershahl
# common → komahn
# community → kahmyuwnahtiy
# company → kumpahniy
# compare → kahmpehr
# computer → kahmpyuwter
# concern → kahnsern
# condition → kahndishahn
# conference → konferahns
# congress → konggrahs
# consider → kahnsider
# consumer → kahnsuwmer
# contain → kahnteyn
# continue → kahntinyuw
# control → kahntrowl
# cost → kost
# could → kud
# country → kuntriy
# couple → kupahl
# course → kors
# court → kort
# cover → kuver
# create → kriyeyt
# crime → kriim
# cultural → kulcherahl
# culture → kulcher
# cup → kup
# current → kerahnt
# customer → kustahmer
# cut → kut
# dark → dork
# data → deytah
# daughter → doter
# day → dey
# dead → dehd
# deal → deel
# death → dehth
# debate → dahbeyt
# decade → dekeyd
# decide → disiid
# decision → disizahn
# deep → deep
# defense → difehns
# degree → digree
# democrat → dehmahkrat
# democratic → demahkratik
# describe → diskriib
# design → diziin
# despite → dispiit
# detail → diteyl
# determine → dahtermahn
# develop → divehlahp
# development → divehlahpmahnt
# die → dii
# difference → diferahns
# different → diferahnt
# difficult → difahkahlt
# dinner → diner
# direction → derehkshahn
# director → derehkter
# discover → diskuver
# discuss → diskus
# discussion → diskushahn
# disease → dizeez
# do → duw
# doctor → dokter
# dog → dog
# door → dor
# down → dawn
# draw → dro
# dream → dreem
# drive → driiv
# drop → drop
# drug → drug
# during → during
# each → eech
# early → erliy
# east → eest
# easy → eeziy
# eat → eet
# economic → ekahnomik
# economy → ikonahmiy
# edge → ehj
# education → ejahkeyshahn
# effect → ifehkt
# effort → ehfert
# eight → eyt
# either → eether
# election → ilehkshahn
# else → ehls
# employee → employiy
# end → ehnd
# energy → ehnerjiy
# enjoy → enjoy
# enough → inuf
# enter → ehnter
# entire → intiier
# environment → inviirahnmahnt
# environmental → invirahnmehntahl
# especially → ahspehshliy
# establish → istablish
# even → eevin
# evening → eevning
# event → ivehnt
# ever → ehver
# every → ehveriy
# everybody → ehvriybadiy
# everyone → ehvriywan
# everything → ehvriything
# evidence → ehvahdahns
# exactly → igzaktliy
# example → igzampahl
# executive → igzehkyahtiv
# exist → igzist
# expect → ikspehkt
# experience → ikspiriyahns
# expert → ehkspert
# explain → ikspleyn
# eye → ii
# face → feys
# fact → fakt
# factor → fakter
# fail → feyl
# fall → fol
# family → famahliy
# far → for
# fast → fast
# father → fother
# fear → fir
# federal → fehderahl
# feel → feel
# feeling → feeling
# few → fyuw
# field → feeld
# fight → fiit
# figure → figyer
# fill → fil
# film → film
# final → fiinahl
# finally → fiinahliy
# financial → fahnanshahl
# find → fiind
# fine → fiin
# finger → fingger
# finish → finish
# fire → fiier
# firm → ferm
# first → ferst
# fish → fish
# five → fiiv
# floor → flor
# fly → flii
# focus → fowkahs
# follow → folow
# food → fuwd
# foot → fut
# for → for
# force → fors
# foreign → forahn
# forget → fergeht
# form → form
# former → former
# forward → forwerd
# four → for
# free → free
# friend → frehnd
# from → frum
# front → frunt
# full → ful
# fund → fund
# future → fyuwcher
# game → geym
# garden → gordahn
# gas → gas
# general → jehnerahl
# generation → jenereyshahn
# get → geht
# girl → gerl
# give → giv
# glass → glas
# go → gow
# goal → gowl
# good → gud
# government → guvermahnt
# great → greyt
# green → green
# ground → grawnd
# group → gruwp
# grow → grow
# growth → growth
# guess → gehs
# gun → gun
# guy → gii
# hair → hehr
# half → haf
# hand → hand
# hang → hang
# happen → hapahn
# happy → hapiy
# hard → hord
# have → hav
# he → hee
# head → hehd
# health → hehlth
# hear → heer
# heart → hort
# heat → heet
# heavy → hehviy
# help → hehlp
# her → her
# here → heer
# herself → hersehlf
# high → hii
# him → him
# himself → himsehlf
# his → hiz
# history → histeriy
# hit → hit
# hold → howld
# home → howm
# hope → howp
# hospital → hospitahl
# hot → hot
# hotel → howtehl
# hour → awer
# house → haws
# how → haw
# however → hawehver
# huge → hyuwj
# human → hyuwmahn
# hundred → hundrahd
# husband → huzbahnd
# i → ii
# idea → ideeah
# identify → idehntahfi
# if → if
# image → imahj
# imagine → imajahn
# impact → impakt
# important → importahnt
# improve → impruwv
# in → in
# include → inkluwd
# including → inkluwding
# increase → inkrees
# indeed → indeed
# indicate → indahkeyt
# individual → indahvijahwahl
# industry → indahstriy
# information → infermeyshahn
# inside → insiid
# instead → instehd
# institution → instituwshahn
# interest → intrahst
# interesting → intrahsting
# international → internashahnahl
# interview → intervyuw
# into → intuw
# investment → invehstmahnt
# involve → involv
# issue → ishuw
# it → it
# item → iitahm
# its → its
# itself → itsehlf
# job → job
# join → joyn
# just → just
# keep → keep
# key → kee
# kid → kid
# kill → kil
# kind → kiind
# kitchen → kichahn
# know → now
# knowledge → nolahj
# land → land
# language → langgwahj
# large → lorj
# last → last
# late → leyt
# later → leyter
# laugh → laf
# law → lo
# lawyer → loyer
# lay → ley
# lead → lehd
# leader → leeder
# learn → lern
# least → leest
# leave → leev
# left → lehft
# leg → lehg
# legal → leegahl
# less → lehs
# let → leht
# letter → lehter
# level → lehvahl
# lie → lii
# life → liif
# light → liit
# like → liik
# likely → liikliy
# line → liin
# list → list
# listen → lisahn
# little → litahl
# live → liiv
# local → lowkahl
# long → long
# look → luk
# lose → luwz
# loss → los
# lot → lot
# love → luv
# low → low
# machine → mahsheen
# magazine → magahziyn
# main → meyn
# maintain → meynteyn
# major → meyjer
# majority → mahjorahtiy
# make → meyk
# man → man
# manage → manahj
# management → manahjmahnt
# manager → manahjer
# many → mehniy
# market → morkaht
# marriage → mehrij
# material → mahtiriyahl
# matter → mater
# may → mey
# maybe → meybiy
# me → mee
# mean → meen
# measure → mehzer
# media → meediyah
# medical → mehdahkahl
# meet → meet
# meeting → meeting
# member → mehmber
# memory → mehmeriy
# mention → mehnshahn
# message → mehsahj
# method → mehthahd
# middle → midahl
# might → miit
# military → milahteriy
# million → milyahn
# mind → miind
# minute → minaht
# miss → mis
# mission → mishahn
# model → modahl
# modern → modern
# moment → mowmahnt
# money → muniy
# month → munth
# more → mor
# morning → morning
# most → mowst
# mother → muther
# mouth → mawth
# move → muwv
# movement → muwvmahnt
# movie → muwviy
# mr → mister
# mrs → misiz
# much → much
# music → myuwzik
# must → must
# my → mii
# myself → misehlf
# name → neym
# nation → neyshahn
# national → nashahnahl
# natural → nacherahl
# nature → neycher
# near → nir
# nearly → nirliy
# necessary → nehsahseriy
# need → need
# network → nehtwerk
# never → nehver
# new → nuw
# news → nuwz
# newspaper → nuwzpeyper
# next → nehkst
# nice → niis
# night → niit
# no → now
# none → nun
# nor → nor
# north → north
# not → not
# note → nowt
# nothing → nuthing
# notice → nowtahs
# now → naw
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-3f967fbb13b3> in <module>
#       1 # Look at some example words under the new spelling
#       2 for word in popular_words:
# ----> 3     print("{} → {}".format(word, mapWord(word)))
#
# <ipython-input-7-2c8cf8bcbcb3> in mapWord(word)
#       7 # Map a word to a new spelling for that word
#       8 def mapWord(word):
# ----> 9     return ''.join(mapPhoneme(phoneme) for phoneme in dictionary[word.lower()])
#      10
#      11 def mapSloppyWord(sloppyWord):
#
# KeyError: "n't"

# %%
# Debug
term = "a"
print(term, dictionary[term], mapSloppyWord(term))

phoneme = 'AH0'
print(phoneme, examples[phoneme])
for word in examples[phoneme]:
    print("\t{} → {}".format(word, mapWord(word)))
# Out:
# a ['AH0'] ah
# AH0 ['social', 'provide', 'position', 'interest', 'record']
# 	social → sowshahl
# 	provide → prahviid
# 	position → pahzishahn
# 	interest → intrahst
# 	record → rahkord

# %%
# Create a few sample paragraphs
paragraphs = {
    'Moby Dick': "Call me Ishmael. Some years ago — never mind how long precisely — having little or no money in my purse, and nothing particular to interest me on shore, I thought I would sail about a little and see the watery part of the world. It is a way I have of driving off the spleen, and regulating the circulation. Whenever I find myself growing grim about the mouth; whenever it is a damp, drizzly November in my soul; whenever I find myself involuntarily pausing before coffin warehouses, and bringing up the rear of every funeral I meet; and especially whenever my hypos get such an upper hand of me, that it requires a strong moral principle to prevent me from deliberately stepping into the street, and methodically knocking people’s hats off — then, I account it high time to get to sea as soon as I can. This is my substitute for pistol and ball. With a philosophical flourish Cato throws himself upon his sword; I quietly take to the ship. There is nothing surprising in this. If they but knew it, almost all men in their degree, some time or other, cherish very nearly the same feelings towards the ocean with me.",
    'A Confederacy of Dunces': "A green hunting cap squeezed the top of the fleshy balloon of a head. The green earflaps, full of large ears and uncut hair and the fine bristles that grew in the ears themselves, stuck out on either side like turn signals indicating two directions at once. Full, pursed lips protruded beneath the bushy black moustache and, at their corners, sank into little folds filled with disapproval and potato chip crumbs. In the shadow under the green visor of the cap Ignatius J. Reilly’s supercilious blue and yellow eyes looked down upon the other people waiting under the clock at the D.H. Holmes department store, studying the crowd of people for signs of bad taste in dress. Several of the outfits, Ignatius noticed, were new enough and expensive enough to be properly considered offenses against taste and decency. Possession of anything new or expensive only reflected a person’s lack of theology and geometry; it could even cast doubts upon one’s soul.",
    'The Stranger': "Mother died today. Or maybe yesterday, I don’t know. I had a telegram from the home: ‘Mother passed away. Funeral tomorrow. Yours sincerely.’ That doesn’t mean anything. It may have been yesterday.",
    'The Bible': "In the beginning God created the heaven and the earth. And the earth was without form, and void; and darkness was upon the face of the deep. And the Spirit of God moved upon the face of the waters.",
    'American Tabloid': "America was never innocent. We popped our cherry on the boat over and looked back with no regrets. You can’t ascribe our fall from grace to any single event or set of circumstances. You can’t lose what you lacked at conception."
}

# print(textwrap.fill(paragraphs['Moby Dick'], 80))

# %%
# Convert the sample paragraphs
for name in paragraphs:
    print("{}\n{}\n{}\n\n".format(
        mapParagraph(name),
        '_'*80,
        textwrap.fill(mapParagraph(paragraphs[name]), 80)
    ))
# Out:
# mowbiy dik
# ________________________________________________________________________________
# kol mee ishmiyl. sum yirz ahgow — nehver miind haw long prisiisliy — having
# litahl or now muniy in mii pers, ahnd nuthing pertikyahler tuw intrahst mee on
# shor, ii thot ii wud seyl ahbawt ah litahl ahnd see thah woteriy port uv thah
# werld. it iz ah wey ii hav uv driiving of thah spleen, ahnd rehgyahleyting thah
# serkyahleyshahn. wenehver ii fiind misehlf growing grim ahbawt thah mawth;
# wenehver it iz ah damp, drizliy nowvehmber in mii sowl; wenehver ii fiind
# misehlf invowlunteriliy pozing bifor kofin wehrhawziz, ahnd bringing up thah rir
# uv ehveriy fyuwnerahl ii meet; ahnd ahspehshliy wenehver mii hypos geht such an
# uper hand uv mee, that it riykwiierz ah strong morahl prinsahpahl tuw privehnt
# mee frum diliberahtliy stehping intuw thah street, ahnd mahthodikahliy noking
# people’s hats of — thehn, ii ahkawnt it hii tiim tuw geht tuw see az suwn az ii
# kan. this iz mii substahtuwt for pistahl ahnd bol. with ah filahsofikahl flerish
# keytow throwz himsehlf ahpon hiz sord; ii kwiiahtliy teyk tuw thah ship. thehr
# iz nuthing serpriizing in this. if they but nuw it, olmowst ol mehn in thehr
# digree, sum tiim or uther, chehrish vehriy nirliy thah seym feelingz tahwordz
# thah owshahn with mee.
#
#
# ah kahnfehderahsiy uv Dunces
# ________________________________________________________________________________
# ah green hunting kap skweezd thah top uv thah flehshiy bahluwn uv ah hehd. thah
# green earflaps, ful uv lorj irz ahnd ankut hehr ahnd thah fiin brisahlz that
# gruw in thah irz themsehlvz, stuk awt on eether siid liik tern signahlz
# indahkeyting tuw derehkshahnz at wuns. ful, perst lips protruded bineeth thah
# bushiy blak mustash ahnd, at thehr kornerz, sangk intuw litahl fowldz fild with
# disahpruwvahl ahnd pahteytow chip krumz. in thah shadow under thah green viizer
# uv thah kap igneyshahs jey. Reilly’s suwpersiliyahs bluw ahnd yehlow iiz lukt
# dawn ahpon thah uther peepahl weyting under thah klok at thah D.H. howmz
# diportmahnt stor, studiying thah krawd uv peepahl for siinz uv bad teyst in
# drehs. sehvrahl uv thah awtfits, igneyshahs nowtahst, wer nuw inuf ahnd
# ikspehnsiv inuf tuw bee properliy kahnsiderd ahfehnsiz ahgehnst teyst ahnd
# deesahnsiy. pahzehshahn uv ehniything nuw or ikspehnsiv ownliy riflehktid ah
# person’s lak uv thiyolahjiy ahnd jiyomahtriy; it kud eevin kast dawts ahpon
# one’s sowl.
#
#
# thah streynjer
# ________________________________________________________________________________
# muther diid tahdey. or meybiy yehsterdey, ii don’t now. ii had ah tehlahgram
# frum thah howm: ‘Mother past ahwey. fyuwnerahl tahmorow. yurz sincerely.’ that
# doesn’t meen ehniything. it mey hav bin yehsterdey.
#
#
# thah biibahl
# ________________________________________________________________________________
# in thah bigining god kriyeytahd thah hehvahn ahnd thah erth. ahnd thah erth woz
# withawt form, ahnd voyd; ahnd dorknahs woz ahpon thah feys uv thah deep. ahnd
# thah spiraht uv god muwvd ahpon thah feys uv thah woterz.
#
#
# ahmehrahkahn tabloyd
# ________________________________________________________________________________
# ahmehrahkah woz nehver inahsahnt. wee popt awer chehriy on thah bowt owver ahnd
# lukt bak with now rigrehts. yuw can’t ahskriib awer fol frum greys tuw ehniy
# singgahl ivehnt or seht uv serkahmstansahz. yuw can’t luwz wut yuw lakt at
# kahnsehpshahn.

# %%
# Take note of some tough words
toughies = {
    'AH0': ['interest', 'a', 'the', 'analysis', 'towards'],
    'AA1': ['on', 'audience'],
    'ER0': ['forget'],
    'EH1': ['air']
}

for phoneme in toughies:
    for word in toughies[phoneme]:
        print('{} → {}'.format(word, mapSloppyWord(word)))
# Out:
# interest → intrahst
# a → ah
# the → thah
# analysis → ahnalahsahs
# towards → tahwordz
# on → on
# audience → odiyahns
# forget → fergeht
# air → ehr

# %%
list = []
for word in dictionary:
    if word == mapWord(word):
        list.append(word)
len(list)
# Out:
# 5518

# %%
len(list)
# Out:
# 5518

# %%
list = []
for word in popular_words:
    if word == mapSloppyWord(word):
        list.append(word)
list
# Out:
# ['after',
#  'ask',
#  'at',
#  'bad',
#  'bag',
#  'big',
#  'bit',
#  'born',
#  'boy',
#  'bring',
#  'but',
#  'deep',
#  'dog',
#  'drop',
#  'drug',
#  'during',
#  'enjoy',
#  'fast',
#  'feel',
#  'feeling',
#  'film',
#  'finish',
#  'fish',
#  'for',
#  'form',
#  'former',
#  'free',
#  'fund',
#  'gas',
#  'green',
#  'grow',
#  'growth',
#  'gun',
#  'hand',
#  'hang',
#  'her',
#  'him',
#  'hit',
#  'hot',
#  'if',
#  'in',
#  'indeed',
#  'it',
#  'its',
#  'job',
#  'just',
#  'keep',
#  'kid',
#  'land',
#  'last',
#  'list',
#  'long',
#  'lot',
#  'low',
#  'man',
#  'meet',
#  'meeting',
#  'modern',
#  'morning',
#  'much',
#  'must',
#  'need',
#  'nor',
#  'north',
#  'not',
#  "n't",
#  'number',
#  'on',
#  'or',
#  'order',
#  'own',
#  'owner',
#  'past',
#  'per',
#  'perform',
#  'perhaps',
#  'plan',
#  'plant',
#  'push',
#  'put',
#  'rather',
#  'rich',
#  'risk',
#  'run',
#  'see',
#  'seek',
#  'seem',
#  'short',
#  'shot',
#  'show',
#  'sing',
#  'sister',
#  'sit',
#  'skin',
#  'song',
#  'sort',
#  'speech',
#  'sport',
#  'spring',
#  'stand',
#  'stop',
#  'street',
#  'strong',
#  'such',
#  'task',
#  'term',
#  'than',
#  'that',
#  'they',
#  'thing',
#  'this',
#  'three',
#  'throw',
#  'thus',
#  'top',
#  'tree',
#  'trip',
#  'under',
#  'up',
#  'us',
#  'week',
#  'win',
#  'window',
#  'wish',
#  'with',
#  'within']

# %%
list = []
for word in popular_words:
    if (len(mapSloppyWord(word)) - len(word)) >= 5:
        list.append(word)
for word in list:
    print(word, mapSloppyWord(word))
# Out:
# sexual sehkshuwahl
# usually yuwzahwahliy

# %%
list = []
for word in dictionary:
    if (len(mapSloppyWord(word)) - len(word)) >= 6:
        list.append(word)
for word in list:
    print(word, mapSloppyWord(word))
# Out:
# aaa tripahley
# accumulation ahkyuwmyahleyshahn
# accumulations ahkyuwmyahleyshahnz
# ach eyseeeych
# adhd eydiyeychdee
# adsl eydiyesehl
# agrarianism ahgrehriyahnizahm
# ahasuerus ahhashahwehrahs
# americanization ahmerahkahnahzeyshahn
# anfal eyehnehfeyehl
# antidisestablishmentarianism antidisahstablishmahntehriyahnizahm
# asap eyehseypee
# asexual eysehksyuwahl
# atx eyteeehks
# authoritarianism ahthorahtehriyahnizahm
# bbc biybiysee
# bbq beebiykyuw
# bmw beeemdubahlyuw
# byu beewiiyuw
# cbc siybiysee
# cbs siybiyehs
# ccd siysiydee
# ccs seeseeehs
# cctv seesiyteeviy
# cdc siydiysee
# cmu seeehmyuw
# cnbc's seeehnbeeseez
# cnn seeehnehn
# cnn.com seeehnehndotkom
# cnnfn seeehnehnehfehn
# coeducational kowehjahkeyshahnahl
# colonialism kahlowniyahlizahm
# conceptualization kahnsehpchwahlizeyshahn
# confucianism kahnfyuwshahnizahm
# cps seepiyehs
# cpu siypiyyuw
# cspi seeehspeeii
# csv seeehsvee
# cxc seeehkssee
# ddt diydiytee
# decriminalization diykrimahnahlahzeyshahn
# dehumanization diyhyuwmahnahzeyshahn
# deinstitutionalization diyinstituwshahnahlahzeyshahn
# denuclearization diynuwkliyerahzeyshahn
# deoxyribonucleic diyaksiyribownuwkleyik
# deregulatory diyrehgyahlahtoriy
# destabilization diysteybahlahzeyshahn
# dfw deeehfdubahlyuw
# dss deeehsehs
# dsv deeehsvee
# dvd diyviydee
# dvds diyviydeez
# dwi deedubahlyuwii
# egalitarianism iygalahtehriyahnizahm
# emdr eeehmdeeor
# entrepreneurialism entrahprahnuwreeahlizahm
# espn eeehspeeehn
# etc etsehterah
# etc. etsehterah.
# excommunicated ekskahmyuwnahkeytahd
# excommunication ekskahmyuwnahkeyshahn
# feb fehbyahweriy
# fyi foryorinfermeyshahn
# gdp geedeepee
# gnc jeeehnsee
# gps geepiyehs
# gumucio gyuwmyuwsiyow
# hbo eychbiyow
# hces eychseeeeehs
# heterosexual heterowsehkshahwahl
# heterosexuality heterowsekshahwalitiy
# heterosexuals heterowsehkshahwahlz
# hfdf eychehfdeeehf
# hgh eychjeeeych
# hiaa eychiieyey
# hiv eychiivee
# homosexual howmowsehkshawahl
# homosexuality howmowsekshuwalahtiy
# homosexuals howmowsehkshuwahlz
# hsbc eychehsbeesee
# html eychtiyemehl
# http eychtiytiypee
# humanitarian hyuwmanahtehriyahn
# humanitarians hyuwmanahtehriyahnz
# ieee itriplahee
# inmobiliaria inmowbahliyehriyah
# inocencio inowchehnchiyow
# kgb keyjiybee
# kkk keykeykey
# knbc keyehnbeesee
# knin keyehniiehn
# kpmg keypeeehmji
# kwh keydubahlyuweych
# lapd ehleypeedee
# lapd's ehleypeedeez
# lcs ehlseeehs
# locicero lowchiychehrow
# lpn ehlpeeehn
# metrosexual metrahsehkshuwahl
# micropaleontology mikrowpeyliyahntolahjiy
# mpg ehmpeejee
# mph ehmpeeeych
# msgr manseenyer
# mtv ehmteevee
# mutualism myuwchuwalizahm
# naacp eneyeysiypee
# nbc ehnbiysee
# negotiated nahgowshiyeytahd
# negotiations nahgowshiyeyshahnz
# neopositivism niyowpozahtahvizahm
# nfc ehnehfsee
# npr.org ehnpeeordotorg
# nypd enwiipiydiy
# oecd owiysiydee
# parliamentarianism parlahmahntehriyahnizahm
# pdf piydiyehf
# peculiarity pikyuwliyehrahtiy
# pgm peejeeehm
# phd peeeychdee
# phlcorp peeeychehlkorp
# php peeeychpee
# ppm peepeeehm
# ptsd piyteeesdee
# pvc piyviysee
# recapitalizations riykapahtahlahzeyshahnz
# renegotiation riynigowshiyeyshahn
# renegotiations riynigowshiyeyshahnz
# reunification riyuwnahfahkeyshahn
# revaluations riyivalyuweyshahnz
# revolucionario revowluwsiyahnehriyow
# ricostruzione riykowstruwziyowniy
# rsvp orehsveepee
# sdn ehsdeeehn
# septuagenarian sepchuwahjahnehriyahn
# singularity singgyahlehrahtiy
# sql eskyuwehl
# ssn ehsehsehn
# stds ehsteedeez
# suu ehsyuwyuw
# tcas teeseeeyehs
# telecommunications telahkahmyuwnahkeyshahnz
# telecommunications' telahkahmyuwnahkeyshahnz'
# totalitarianism towtalahtehriyahnizahm
# unification yuwnahfahkeyshahn
# unionization yuwnyahnahzeyshahn
# unitarian yuwnahtehriyahn
# usb yuwehsbee
# usda yuwesdiyey
# usmc yuwehsehmsee
# utilitarian yuwtilahtehriyahn
# utilization yuwtahlahzeyshahn
# vegetarianism vejahtehriyahnizahm
# w dubahlyuw
# w's dubahlyuwz
# w. dubahlyuw.
# w.'s dubahlyuwz
# w.s dubahlyuwz
# ws dubahlyuwehs
